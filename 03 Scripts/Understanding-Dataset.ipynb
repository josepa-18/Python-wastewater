# %% [markdown]
# # 1. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 2. Importing dataset

# %%
df = pd.read_csv(r'C:\Users\Josepa Cusidó\EU_Drugs_Wastewater\02 Data\Wastewater drug residues_ORIGINAL.csv', index_col = False)

# %%
path = r'C:\Users\Josepa Cusidó\EU_Drugs_Wastewater'

# %%
path
# Out:
# 'C:\\Users\\Josepa Cusidó\\EU_Drugs_Wastewater'

# %%
df.shape
# Out:
# (2569, 15)

# %%
df.dtypes
# Out:
# year              int64
# metabolite       object
# SiteID           object
# country          object
# city             object
# Wednesday       float64
# Thursday        float64
# Friday          float64
# Saturday        float64
# Sunday          float64
# Monday          float64
# Tuesday         float64
# Weekday mean    float64
# Weekend mean    float64
# Daily mean      float64
# dtype: object

# %%
df.describe()
# Out:
#               year    Wednesday     Thursday       Friday     Saturday  \
# count  2569.000000  2551.000000  2523.000000  2537.000000  2546.000000
# mean   2017.302452    78.992301    80.713781    87.122803   104.187133
# std       2.860870   141.770603   146.829923   157.248813   187.438838
# min    2011.000000     0.000000     0.000000     0.000000     0.000000
# 25%    2015.000000     4.360000     4.060000     4.400000     6.320000
# 50%    2018.000000    19.430000    18.450000    20.890000    31.290000
# 75%    2020.000000    82.645000    82.980000    89.960000   101.680000
# max    2021.000000  1423.910000  1556.200000  1594.080000  1806.010000
#
#             Sunday       Monday      Tuesday  Weekday mean  Weekend mean  \
# count  2533.000000  2533.000000  2535.000000   2568.000000   2569.000000
# mean    109.720904    89.065898    83.962276     81.199607     97.929260
# std     198.120029   156.694279   166.977673    146.737828    172.108124
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2569 entries, 0 to 2568
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          2569 non-null   int64
#  1   metabolite    2569 non-null   object
#  2   SiteID        2569 non-null   object
#  3   country       2569 non-null   object
#  4   city          2569 non-null   object
#  5   Wednesday     2551 non-null   float64
#  6   Thursday      2523 non-null   float64
#  7   Friday        2537 non-null   float64
#  8   Saturday      2546 non-null   float64
#  9   Sunday        2533 non-null   float64
#  10  Monday        2533 non-null   float64
#  11  Tuesday       2535 non-null   float64
#  12  Weekday mean  2568 non-null   float64
#  13  Weekend mean  2569 non-null   float64
#  14  Daily mean    2569 non-null   float64
# dtypes: float64(10), int64(1), object(4)
# memory usage: 301.2+ KB

# %%
df.columns
# Out:
# Index(['year', 'metabolite', 'SiteID', 'country', 'city', 'Wednesday',
#        'Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday',
#        'Weekday mean', 'Weekend mean', 'Daily mean'],
#       dtype='object')

# %% [markdown]
# # 3. Data Profile

# %% [markdown]
# ## Finding duplicates

# %%
df.drop_duplicates()
# Out:
#       year       metabolite SiteID country          city  Wednesday  Thursday  \
# 0     2021      amphetamine  AT001      AT          Graz      47.15     37.48
# 1     2021      amphetamine  AT002      AT  Hall-Wattens       8.37      7.08
# 2     2021      amphetamine  AT004      AT     Innsbruck      16.59     16.72
# 3     2021      amphetamine  AT005      AT    Kapfenberg      25.01     24.11
# 4     2021      amphetamine  AT007      AT      Kufstein      24.24     16.19
# ...    ...              ...    ...     ...           ...        ...       ...
# 2564  2011  methamphetamine  NL001      NL     Amsterdam       0.00      0.00
# 2565  2011  methamphetamine  NL002      NL     Eindhoven       0.00      0.00
# 2566  2011  methamphetamine  NL005      NL       Utrecht       0.00      0.00
# 2567  2011  methamphetamine  NO001      NO          Oslo     235.00    212.60
# 2568  2011  methamphetamine  SE007      SE          Umea       3.91      4.37
#
# ...

# %% [markdown]
# ## Finding missing values

# %%
df.isnull().sum()
# Out:
# year             0
# metabolite       0
# SiteID           0
# country          0
# city             0
# Wednesday       18
# Thursday        46
# Friday          32
# Saturday        23
# Sunday          36
# Monday          36
# Tuesday         34
# Weekday mean     1
# Weekend mean     0
# Daily mean       0
# dtype: int64

# %%
df['Wednesday'].fillna(df['Weekday mean'], inplace=True)

# %%
df['Thursday'].fillna(df['Weekday mean'], inplace=True)

# %%
df['Friday'].fillna(df['Weekday mean'], inplace=True)

# %%
df['Monday'].fillna(df['Weekday mean'], inplace=True)

# %%
df['Tuesday'].fillna(df['Weekday mean'], inplace=True)

# %%
df['Saturday'].fillna(df['Weekend mean'], inplace=True)

# %%
df['Sunday'].fillna(df['Weekend mean'], inplace=True)

# %%
df.isnull().sum()
# Out:
# year            0
# metabolite      0
# SiteID          0
# country         0
# city            0
# Wednesday       1
# Thursday        1
# Friday          0
# Saturday        0
# Sunday          0
# Monday          0
# Tuesday         1
# Weekday mean    1
# Weekend mean    0
# Daily mean      0
# dtype: int64

# %%
df['Weekday mean'].fillna(df['Daily mean'], inplace=True)

# %%
df['Wednesday'].fillna(df['Weekday mean'], inplace=True)

# %%
df['Thursday'].fillna(df['Weekday mean'], inplace=True)

# %%
df['Tuesday'].fillna(df['Weekday mean'], inplace=True)

# %%
df.isnull().sum()
# Out:
# year            0
# metabolite      0
# SiteID          0
# country         0
# city            0
# Wednesday       0
# Thursday        0
# Friday          0
# Saturday        0
# Sunday          0
# Monday          0
# Tuesday         0
# Weekday mean    0
# Weekend mean    0
# Daily mean      0
# dtype: int64

# %% [markdown]
# ## Deleting rows with 0

# %%
df.drop = df[ (df['Wednesday'] == 0) & (df['Thursday'] == 0 ) & (df['Friday'] == 0 ) & (df['Saturday'] == 0 ) & (df['Sunday'] == 0 ) & (df['Monday'] == 0 ) & (df['Tuesday'] == 0 )]

# %%
df.shape
# Out:
# (2316, 15)

# %% [markdown]
# ## Aggregating columns

# %%
df.groupby('year').agg({'year':['count']})
# Out:
#       year
#      count
# year
# 2011    56
# 2012    82
# 2013   145
# 2014   157
# 2015   163
# 2016   178
# 2017   220
# 2018   307
# 2019   306
# 2020   374
# 2021   328

# %%
df.groupby('metabolite').agg({'metabolite':['count']})
# Out:
#                 metabolite
#                      count
# metabolite
# MDMA                   572
# amphetamine            499
# cannabis               208
# cocaine                594
# methamphetamine        443

# %%
df.groupby('SiteID').agg({'SiteID':['count']})
# Out:
#        SiteID
#         count
# SiteID
# AT001      15
# AT002      20
# AT003      19
# AT004      28
# AT005      15
# ...       ...
# SK002      16
# SK004      27
# TR001      12
# TR002       2
# TR003      13
#
# [143 rows x 1 columns]

# %%
df.groupby('country').agg({'country':['count']})
# Out:
#         country
#           count
# country
# AT          154
# BA            3
# BE          189
# CH          185
# CY           46
# CZ          104
# DE          240
# DK           26
# EE            4
# ES          156
# FI          377
# FR           44
# GB           36
# GR           43
# HR           42
# IS           25
# IT           62
# LT           52
# LV           12
# MT            3
# NL          123
# NO           42
# PL           18
# PT           85
# RS           11
# SE           76
# SI           88
# SK           43
# TR           27

# %%
df.groupby('city').agg({'city':['count']}, pd.set_option('display.max_rows', None))
# Out:
#                         city
#                        count
# city
# Adana                     12
# Agia Napa                  4
# Almada                    31
# Amsterdam                 45
# Antwerp Deurne            22
# Antwerp Zuid              45
# Athens                    35
# Barcelona                 46
# Basel                     34
# Belgrade                   4
# Berlin (4)                16
# Berne                     41
# Boom                      11
# Bordeaux I                10
# Bozen                     19
# Bratislava C              16
# Bristol                   21
# Brno                      16
# Brugge                     3
# Brussels                  41
# Budweis                   39
# Castellon                 28
# Chemnitz                  18
# Copenhagen                22
# Domžale-Kamnik            16
# Dortmund                  30
# Dresden                   34
# Dülmen                    29
# Eindhoven                 31
# Eleusis                    5
# ...

# %%
df.describe()
# Out:
#               year    Wednesday     Thursday       Friday     Saturday  \
# count  2316.000000  2316.000000  2316.000000  2316.000000  2316.000000
# mean   2017.454231    87.680449    89.349650    96.643238   115.625946
# std       2.811282   146.772677   151.672173   162.654644   194.074347
# min    2011.000000     0.080000     0.000000     0.080000     0.000000
# 25%    2015.000000     7.065000     6.980000     8.177500    11.130000
# 50%    2018.000000    25.720000    24.975000    27.220000    39.290000
# 75%    2020.000000    96.655000    95.990000   104.162500   120.745000
# max    2021.000000  1423.910000  1556.200000  1594.080000  1806.010000
#
#             Sunday       Monday      Tuesday  Weekday mean  Weekend mean  \
# count  2316.000000  2316.000000  2316.000000   2316.000000   2316.000000
# mean    122.318739    99.155509    93.278610     90.037310    108.627060
# std     205.961181   162.314109   173.321053    151.919732    178.033295
# ...

# %%
df.to_csv(os.path.join(path, '02 Data', 'Wastewater drug residues_CLEAN.csv'))
